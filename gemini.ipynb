# %% [markdown]
# <a href="https://colab.research.google.com/github/Gabriel1Vitor/Chatbot-Gemini/blob/main/gemini.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![imagem_2024-05-13_123549570.png](data:image/png;base64,...)
#
#
# **Este código foi criado para à imersão da Alura e do Google, utilizando o Gemini. Fiz um chatbot padrão, mas com uma resposta tanto em áudio quanto em texto.**

# %%
# !pip install -q -U google-generativeai
# !pip install -q -U  gtts

# %%
import google.generativeai as genai
import os
from google.colab import userdata
import pathlib
import textwrap
from IPython.display import display
from IPython.display import Markdown

GOOGLE_API_KEY='key_GOOGLE'

genai.configure(api_key=GOOGLE_API_KEY)

def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))


for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
    print(m.name)

model = genai.GenerativeModel('models/gemini-pro')
# Out:
# models/gemini-1.0-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro-vision-latest
# models/gemini-1.5-pro-latest
# models/gemini-pro
# models/gemini-pro-vision

# %%
df = input()
texto = ['em texto simples']

df = df + " ".join(texto)

response = model.generate_content(df)
to_markdown(response.text)


from gtts import gTTS

def text_to_speech(text, language='pt'):
  output = gTTS(text=text, lang=language, slow=False)
  output.save("output.mp3")

text = response.text

text_to_speech(text)

from IPython.display import Audio

audio = '/content/output.mp3'

print(text)
Audio(audio)
# Out:
# resume para mim sobre conan o barbaro?
# Conan é um bárbaro poderoso e destemido que viaja pelas Terras Amaldiçoadas em busca de aventura e vingança. Com sua espada mágica e força extraordinária, ele enfrenta monstros, bruxas e exércitos inteiros em busca de glória e redenção por sua família assassinada.
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# **Aqui quero colocar uma coisa que encontrei no gemini. Ele precisa ser mais treinado, pois não sabe o que é uma fissão nuclear.**
